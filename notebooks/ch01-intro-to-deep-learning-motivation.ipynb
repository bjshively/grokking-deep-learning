# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline
plt.rcParams["figure.figsize"] = (8, 5)
plt.rcParams["axes.grid"] = True

print("NumPy version:", np.__version__)

# %% [markdown]
# # Chapter 01 – Intro to Deep Learning & Motivation
#
# > Work for this chapter of *Grokking Deep Learning*.
#
# ## 1. Quick notes (5–10 bullets, in my own words)
#
# - This chapter is basically about why to learn deep learning and what skills are required
# - The book covers the key concepts of deep learning without requiring strong math skills (basically just high school algebra)
# - The book implements the concepts using foundational python rather than a library like PyTorch to help reinforce the core concepts and avoid abstracting away too much of what is actually happening
# - This will be good foundational knowledge to understand what's happening under the hood when using deep learning libraries in the future

# %%
# 2. Code from the book
#
# no code in this chapter

# %%
# 3. One tiny experiment (<= 5 minutes)
#
# n/a
